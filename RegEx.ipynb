# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdansu333/python/blob/main/RegEx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RegEx - Regular Expression
#
#
# Regular expressions (called REs, or regexes, or regex patterns) are essentially a tiny, highly specialized programming language embedded inside Python and made available through the re module
#
# Using this little language, you specify the rules for the set of possible strings that you want to match; this set might contain English sentences, or e-mail addresses, or TeX commands, or anything you like.

# %%
import re

txt = "The rain in Spain"
x = re.search("^The.Spain$", txt)

# %%
print(dir(x))
# Out:
# ['__class__', '__class_getitem__', '__copy__', '__deepcopy__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'end', 'endpos', 'expand', 'group', 'groupdict', 'groups', 'lastgroup', 'lastindex', 'pos', 're', 'regs', 'span', 'start', 'string']

# %% [markdown]
# ![Screenshot 2023-09-11 at 5.01.38 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-09-11 at 5.03.14 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-09-11 at 5.03.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-09-11 at 5.04.53 PM.png](data:image/png;base64,...)

# %% [markdown]
# # The findall() Function
#
# The findall() function returns a list containing all matches.

# %%
import re

txt = "The rain in Spain rain"
x = re.findall("rain", txt)
print(x)
# Out:
# ['rain', 'rain']

# %% [markdown]
# The list contains the matches in the order they are found.
#
# If no matches are found, an empty list is returned:

# %%
import re

txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
# Out:
# []

# %% [markdown]
# # The search() Function
#
# The search() function searches the string for a match, and returns a Match object if there is a match.
#
# If there is more than one match, only the first occurrence of the match will be returned:

# %%
import re

txt = "The rain  in Spain"
x = re.search(r"\s", txt)

print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %% [markdown]
# If no matches are found, the value None is returned:

# %% [markdown]
# # The split() Function
# The split() function returns a list where the string has been split at each match:

# %%
import re

txt = "The 5rain in 3Spa in"
x = re.split(r"", txt)
print(x)
# Out:
# ['', 'T', 'h', 'e', ' ', '5', 'r', 'a', 'i', 'n', ' ', 'i', 'n', ' ', '3', 'S', 'p', 'a', ' ', 'i', 'n', '']

# %% [markdown]
# You can control the number of occurrences by specifying the maxsplit parameter:

# %%
#Split the string only at the first occurrence:


import re

txt = "The rain in Spain hi"
x = re.split("\s", txt, 3)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain hi']

# %% [markdown]
# # The sub() Function
#
# The sub() function replaces the matches with the text of your choice:

# %%
# Replace every white-space character with the number 9:

import re

txt = "The rain in Spain"
x = re.sub("\sin", " 9", txt)
print(x)
# Out:
# The rain 9 Spain

# %% [markdown]
# You can control the number of replacements by specifying the count parameter:

# %%
# Replace the first 2 occurrences:

import re

txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain

# %% [markdown]
# # Match Object
# A Match Object is an object containing information about the search and the result.
#
# ```Note: If there is no match, the value None will be returned, instead of the Match Object.```

# %%
#Do a search that will return a Match Object:

import re

txt = "The rain in Spain"
x = re.search("in", txt)
print(x) #this will print an object
# Out:
# <re.Match object; span=(6, 8), match='in'>

# %% [markdown]
# The Match object has properties and methods used to retrieve information about the search, and the result:
#
# * `.span()` returns a tuple containing the start-, and end positions of the match.
# * `.string` returns the string passed into the function
# * `.group()` returns the part of the string where there was a match

# %% [markdown]
# Print the position (start- and end-position) of the first match occurrence.

# %%
# The regular expression looks for any words that starts with an upper case "S":

import re

txt = "The rain in  Spain "
x = re.search(r"\bS\w+\s", txt)
print(x.span())
# Out:
# (13, 19)

# %%
# Print the string passed into the function:

import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
#Print the part of the string where there was a match.

#The regular expression looks for any words that starts with an upper case "S":

import re

txt = "The rain in Spain rain"
x = re.search(r"\br\w+$", txt)
print(x.group())
# Out:
# rain

# %% [markdown]
# `^a...s$` : This code defines a RegEx pattern. The pattern is: any five letter string starting with `a` and ending with `s`.
#
# ![Screenshot 2023-09-11 at 5.27.33 PM.png](data:image/png;base64,...)

# %%
import re

pattern = '^a...s$'
test_string = 'abysx'
result = re.search(pattern, test_string)
# print(result)
if result:
  print("Search successful.")
else:
  print("Search unsuccessful.")
# Out:
# Search unsuccessful.

# %% [markdown]
# Here, we used `re.match()` function to search pattern within the test_string. The method returns a match object if the search is successful. If not, it returns None.

# %% [markdown]
# `[]` - Square brackets \
# Square brackets specifies a set of characters you wish to match.

# %% [markdown]
# ![Screenshot 2023-09-11 at 5.36.10 PM.png](data:image/png;base64,...)

# %% [markdown]
# Here, `[abc]` will match if the string you are trying to match contains any of the a, b or c. \
#
# You can also specify a range of characters using - inside square brackets.
#
# `[a-e]` is the same as `[abcde]`. \
# `[1-4]` is the same as `[1234]`.  \
# `[0-39]` is the same as `[01239]`.  \
#
# You can complement (invert) the character set by using caret `^` symbol at the start of a square-bracket.
#
# `[^abc]` means any character except a or b or c. \
# `[^0-9]` means any non-digit character.

# %% [markdown]
# [Regex](https://www.programiz.com/python-programming/regex)
